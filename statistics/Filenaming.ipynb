# %%
levelList = ["Level 1", "Level 2", "Level 3", "Level 4", "Level 5", "Level 6"]

for i in range(len(levelList)):
    open(f"{levelList[i]} Win Statistic.txt", "x")
    open(f"{levelList[i]} Loss Statistic.txt", "x")
    with open(f"{levelList[i]} Win Statistic.txt", "w") as filename:
        filename.write("0")
    with open(f"{levelList[i]} Loss Statistic.txt", "w") as filename:
        filename.write("0")

print("Empty Files Created.")
print("For real this time")
# Out:
# Empty Files Created.
# For real this time
